# %% [markdown]
# <a href="https://colab.research.google.com/github/sohyeon1202/ai_python/blob/main/240517.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#역대 박스오피스 파일을 데이터프레임으로 생성하기
#1. 데이터프레임을 생성한 후 데이터프레임의 정보를 출력하시오
#2. 대표국적별 영화편수를 집계
#3. 대표국적이 '영국'인 데이터 출력
#4. 대표국적별 최상위 순위 출력
import pandas as pd
df = pd.read_excel('BoxOffice.xlsx')
df.value_counts('대표국적')
df[df['대표국적']=='영국']
df.groupby('대표국적')['순위'].min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-170449907c1e> in <cell line: 7>()
#       5 #4. 대표국적별 최상위 순위 출력
#       6 import pandas as pd
# ----> 7 df = pd.read_xlsx('BoxOffice.xlsx')
#       8 df.value_counts('대표국적')
#       9 df[df['대표국적']=='영국']
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
df = pd.read_excel('data1.xlsx')

plt.plot(df['kor'], '--', marker='o')
plt.show()

# %%
df = pd.read_excel('data1.xlsx')

plt.plot(df['kor'],'--', marker='o', label = 'kor')
plt.plot(df['math'], marker ='^', label='math')
plt.legend()
plt.show()

# %%
df = pd.DataFrame({'요일' : ['월', '화', '수','목','금','토','일'], '공부시간' : [2,3,1,5,4,2,1], '성적' :[70,75,65,85,80,70,60]})

plt.plot(df['요일'], df['공부시간'])
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.plot(df['요일'], df['성적'])

# %%
plt.scatter(df['공부시간'], df['성적'])

# %%
import numpy as np

x = np.arange(1,11)
y = np.random.randint(1,30,10)

plt.scatter(x,y)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
df = pd.DataFrame({'도시' : ['서울','부산','인천','대구'],
                   '인구 수' : [9904312,3448737, 2890451, 2466052]})
plt.rc('font', family='NanumGothic')
plt.bar(df['도시'], df['인구 수'])
plt.title('도시별 인구 수')
plt.xlabel('도시')
plt.ylabel('인구 수')
# Out:
# Text(0, 0.5, '인구 수')

# %%
import pandas as pd
df = pd.read_excel('data1.xlsx')

plt.plot(df['name'], df['kor'], 'g--', marker = 'o', label='국어점수')
plt.plot(df['name'], df['math'], 'r', marker='v', label='수학점수')
plt.title('성적별 그래프')
plt.xlabel('이름')
plt.ylabel('점수')
plt.legend()
plt.show()

# %%
import seaborn as sns
iris_data=pd.read_csv('iris.csv')
sns.scatterplot(x='petal_length',y='petal_width'
,hue='species',data= iris_data)
plt.title('Scatter Plot by seaborn', fontsize=20)
plt.show()

# %%
data1 = pd.DataFrame({
'category': ['A', 'B', 'A', 'C', 'B', 'A', 'A', 'C', 'B', 'B'],
'value': [10, 20, 15, 25, 30, 12, 18, 22, 28, 35]})
sns.countplot(x='category',data=data1)

plt.show()

# %%
pdata=pd.read_csv('penguins.csv')
sns.barplot(x='species',y='body_mass_g',data=pdata, hue='sex')

plt.show()

# %%
pd = sns.load_dataset('penguins')
